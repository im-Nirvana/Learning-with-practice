# %%
import pandas as pd
import glob
import os

exec(open("/dbfs/mnt/cis2-casino-niq/onboarding/parameter.py").read())
prevday=prevday  
currday=currday	
prevwk=prevwk #On Tuesdays this is currwk-1
currwk=currwk
chkmon=chkmon  #(---- previous week Monday----)
prevday1=prevday1
prevday2=prevday2 #(Sunday date) Only for Monday's processing
sunddate=sunddate ##Current week's sunday date
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
os.environ['prevday'] = ' '.join({str(prevday)})
print(os.getenv('prevday'))

os.environ['currday'] = ' '.join({str(currday)})
print(os.getenv('currday'))

os.environ['prevwk'] = ' '.join({str(prevwk)})
print(os.getenv('prevwk'))

os.environ['currwk'] = ' '.join({str(currwk)})
print(os.getenv('currwk'))

os.environ['chkmon'] = ' '.join({str(chkmon)})
print(os.getenv('chkmon'))

os.environ['prevday1'] = ' '.join({str(prevday1)})
print(os.getenv('prevday1'))

os.environ['prevday2'] = ' '.join({str(prevday2)})
print(os.getenv('prevday2'))

os.environ['sunddate'] = ' '.join({str(sunddate)})
print(os.getenv('sunddate'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">20221206
# 20221207
# 202249
# 202249
# 20230206
# 20221205
# 20221023
# 20230212
# </div>

# %%
# %run /Shared/Casino_Daily/No_Dependency/load_trans_daily_EP1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
# ...

# %%
# %run /Shared/Casino_Daily/No_Dependency/load_trans_daily_EP2

# %%
# %run /Shared/Casino_Daily/No_Dependency/load_daily_AV1

# %%
# %run /Shared/Casino_Daily/No_Dependency/load_daily_AV2

# %%
# %run /Shared/Casino_Daily/No_Dependency/load_cfr_daily

# %%
# %run /Shared/Casino_Daily/Dependency/create_week_nonewref
